# %%
import pandas as pd
import random 

dataset=pd.read_csv('book2.csv', encoding='latin1')
print(dataset)
# Out:
#                                  location       lat      long
# 0                                hava lux  4.155655  9.265483
# 1                          ice spark inno  4.154224  9.265482
# 2                            ellis savior  4.153246  9.265681
# 3                      ese kangs longrich  4.155334  9.263480
# 4                       sun shine fasion   4.159345  9.263423
# 5                    fracnzy market place  4.159323  9.263409
# 6                                 DJ jeff  4.159303  9.263419
# 7                         danang vs vilox  4.156109  9.263490
# 8                            soft mind IT  4.156243  9.263917
# 9                        creative shoping  4.156292  9.000000
# 10                            blue lounge  4.156382  9.264297
# 11             easy lift cleaning service  4.156608  9.264816
# 12                            mini caquet  4.155608  9.264981
# 13                       cashshop/renters  4.156680  9.265224
# ...

# %%
cost=[]
for i in range(len(dataset)):
    cost.append(random.randint(1,15))
print(cost)
# Out:
# [12, 3, 7, 6, 11, 8, 9, 6, 1, 13, 1, 9, 14, 14, 1, 8, 3, 9, 11, 10, 9, 15, 2, 1, 4, 14, 10, 9, 3, 11, 3, 11, 12, 15, 7, 15, 1, 8, 4, 11, 5, 15, 1, 13, 7, 3, 2, 6, 7, 9]

# %%
search_graph={}
for i in range(len(dataset)):
    print("i =", i)
    print("dataset.iloc[i]=",dataset.iloc[i])
    print("cost[i]=", cost[i])
# Out:
# i = 0
# dataset.iloc[i]= location    hava lux
# lat          4.15566
# long         9.26548
# Name: 0, dtype: object
# cost[i]= 12
# i = 1
# dataset.iloc[i]= location    ice spark inno
# lat                4.15422
# long               9.26548
# Name: 1, dtype: object
# cost[i]= 3
# i = 2
# dataset.iloc[i]= location    ellis savior
# lat              4.15325
# long             9.26568
# Name: 2, dtype: object
# cost[i]= 7
# i = 3
# dataset.iloc[i]= location    ese kangs longrich
# lat                    4.15533
# long                   9.26348
# Name: 3, dtype: object
# cost[i]= 6
# i = 4
# dataset.iloc[i]= location    sun shine fasion
# lat                   4.15935
# long                  9.26342
# Name: 4, dtype: object
# cost[i]= 11
# i = 5
# dataset.iloc[i]= location    fracnzy market place
# lat                      4.15932
# long                     9.26341
# Name: 5, dtype: object
# cost[i]= 8
# i = 6
# dataset.iloc[i]= location    DJ jeff
# lat          4.1593
# ...

# %%
new_graph={
    
}
i=0
while i<(len(dataset)-1):
    new_graph[dataset.iloc[i,0]]=(dataset.iloc[i,0],dataset.iloc[i+1,1])
    i+=1
for i in new_graph:
    print(i, ":", new_graph[i])
# Out:
# hava lux : ('hava lux', 4.154224)
# ice spark inno : ('ice spark inno', 4.153246)
# ellis savior : ('ellis savior', 4.1553342)
# ese kangs longrich : ('ese kangs longrich', 4.159345)
# sun shine fasion  : ('sun shine fasion ', 4.1593230000000005)
# fracnzy market place : ('fracnzy market place', 4.1593029999999995)
# DJ jeff : ('DJ jeff', 4.156109)
# danang vs vilox : ('danang vs vilox', 4.156243)
# soft mind IT : ('soft mind IT', 4.156292)
# creative shoping : ('creative shoping', 4.156382)
# blue lounge : ('blue lounge', 4.156608)
# easy lift cleaning service : ('easy lift cleaning service', 4.155608)
# mini caquet : ('mini caquet', 4.1566799)
# cashshop/renters : ('cashshop/renters', 4.1567620000000005)
# haustrireluftweg : ('haustrireluftweg', 4.156791)
# ulisfood : ('ulisfood', 4.156827)
# yoliodinology : ('yoliodinology', 4.157036)
# alpharelanguage institude : ('alpharelanguage institude', 4.157036)
# home land shoping : ('home land shoping', 4.1572510000000005)
# ...
